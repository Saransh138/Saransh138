# %%
import numpy as np 
import pandas  as pd

# %%
df = pd.read_csv("HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df1.satisfaction_level.max()
# Out:
# 1.0

# %%
df1.count()
# Out:
# satisfaction_level       14999
# last_evaluation          14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# left                     14999
# promotion_last_5years    14999
# Department               14999
# salary                   14999
# dtype: int64

# %%
df2 = pd.DataFrame(df,columns=['satisfaction_level','Department'])
df2
# Out:
#        satisfaction_level Department
# 0                    0.38      sales
# 1                    0.80      sales
# 2                    0.11      sales
# 3                    0.72      sales
# 4                    0.37      sales
# ...                   ...        ...
# 14994                0.40    support
# 14995                0.37    support
# 14996                0.37    support
# 14997                0.11    support
# 14998                0.37    support
#
# [14999 rows x 2 columns]

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df1.pivot(columns = 'Department')
# Out:
#            satisfaction_level                                            \
# Department                 IT RandD accounting  hr management marketing
# 0                         NaN   NaN        NaN NaN        NaN       NaN
# 1                         NaN   NaN        NaN NaN        NaN       NaN
# 2                         NaN   NaN        NaN NaN        NaN       NaN
# 3                         NaN   NaN        NaN NaN        NaN       NaN
# 4                         NaN   NaN        NaN NaN        NaN       NaN
# ...                       ...   ...        ...  ..        ...       ...
# 14994                     NaN   NaN        NaN NaN        NaN       NaN
# 14995                     NaN   NaN        NaN NaN        NaN       NaN
# 14996                     NaN   NaN        NaN NaN        NaN       NaN
# 14997                     NaN   NaN        NaN NaN        NaN       NaN
# 14998                     NaN   NaN        NaN NaN        NaN       NaN
#
# ...

# %%
df.salary.value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-50ee9d11978e> in <module>
# ----> 1 df.salary.value_count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value_count'
