# %%
import pandas as pd
import requests


url = "https://newsapi.org/v2/everything?"
key = "2c415b0f65e24610b3807aa02d93d369"

# %%
params = {
    'q' : 'bollywood',
    'apiKey' : key
}

# %%
res = requests.get(url, params=params)

# %%
res2 = res.json()
res2
# Out:
# {'status': 'ok',
#  'totalResults': 2657,
#  'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "The Bollywood legend hailed as India's Marlon Brando",
#    'description': 'Lord Meghnad Desai remembers Bollywood actor Dilip Kumar.',
#    'url': 'https://www.bbc.co.uk/news/world-asia-india-24140485',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/71D9/production/_119254192_dilip.jpg',
#    'publishedAt': '2021-07-07T02:49:17Z',
#    'content': "image captionDilip Kumar was one of Bollywood's best-known actors\r\nDilip Kumar was arguably the best actor Indian cinema has produced, writes Lord Meghnad Desai, eminent economist and Dilip Kumar's b… [+4692 chars]"},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Manveena Suri and Jessie Yeung | Vedika Sud, CNN',
#    'title': 'Dilip Kumar, legendary Bollywood star, dies at 98',
# ...

# %%
res2['articles'][2]['content']
# Out:
# 'image copyrightGetty Images\r\nIndian screen and stage star Surekha Sikri has been described as a "top-class actor" and a "force of nature" following her death at the age of 75.\r\nThe veteran, known for… [+2202 chars]'

# %%
res2['articles']
# Out:
# [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'https://www.facebook.com/bbcnews',
#   'title': "The Bollywood legend hailed as India's Marlon Brando",
#   'description': 'Lord Meghnad Desai remembers Bollywood actor Dilip Kumar.',
#   'url': 'https://www.bbc.co.uk/news/world-asia-india-24140485',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/71D9/production/_119254192_dilip.jpg',
#   'publishedAt': '2021-07-07T02:49:17Z',
#   'content': "image captionDilip Kumar was one of Bollywood's best-known actors\r\nDilip Kumar was arguably the best actor Indian cinema has produced, writes Lord Meghnad Desai, eminent economist and Dilip Kumar's b… [+4692 chars]"},
#  {'source': {'id': 'cnn', 'name': 'CNN'},
#   'author': 'Manveena Suri and Jessie Yeung | Vedika Sud, CNN',
#   'title': 'Dilip Kumar, legendary Bollywood star, dies at 98',
# ...

# %%
pd.DataFrame(res2['articles'])
# Out:
#                                               author  \
# 0                   https://www.facebook.com/bbcnews
# 1   Manveena Suri and Jessie Yeung | Vedika Sud, CNN
# 2                   https://www.facebook.com/bbcnews
# 3                                         Jon Porter
# 4                                            Reuters
# 5                     Hannah Ellis-Petersen in Delhi
# 6                                   Story by Reuters
# 7                                      Tribune India
# 8                                            Reuters
# 9                                   Yahoo News Video
# 10                                     Shahnaz Habib
# 11                                     Tribune India
# 12                                           Reuters
# 13                                     Reuters Staff
# 14                               Mashable News Staff
# 15                                      Qais Hussain
# 16                                        Al Jazeera
# ...
